# %% [markdown]
# ___
#
# ## Preparando o ambiente
#
# Instalando a biblioteca *tweepy* para realizar a conexão com o Twitter:

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %% [markdown]
# Importando as Bibliotecas que serão utilizadas. Esteja livre para adicionar outras.

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle

# %% [markdown]
# ___
# ## Autenticando no  Twitter
#
# Para realizar a captura dos dados é necessário ter uma conta cadastrada no twitter:
#
# * Conta: ***[@pedroazambuja14]***
#
#
# 1. Caso ainda não tenha uma: https://twitter.com/signup
# 1. Depois é necessário registrar um app para usar a biblioteca: https://apps.twitter.com/
# 1. Dentro do registro do App, na aba Keys and Access Tokens, anotar os seguintes campos:
#     1. Consumer Key (API Key)
#     1. Consumer Secret (API Secret)
# 1. Mais abaixo, gere um Token e anote também:
#     1. Access Token
#     1. Access Token Secret
#
# 1. Preencha os valores no arquivo "auth.pass"
#
# **ATENÇÃO**: Nunca divulgue os dados desse arquivo online (GitHub, etc). Ele contém as chaves necessárias para realizar as operações no twitter de forma automática e portanto é equivalente a ser "hackeado". De posse desses dados, pessoas mal intencionadas podem fazer todas as operações manuais (tweetar, seguir, bloquear/desbloquear, listar os seguidores, etc). Para efeito do projeto, esse arquivo não precisa ser entregue!!!

# %%
#Dados de autenticação do twitter: 

#Coloque aqui o identificador da conta no twitter: @pedroazambuja14

#leitura do arquivo no formato JSON
with open('auth.pass') as fp:    
    data = json.load(fp)

#Configurando a biblioteca. Não modificar
auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
auth.set_access_token(data['access_token'], data['access_token_secret'])

# %% [markdown]
# ___
# ## Coletando Dados
#
# Agora vamos coletar os dados. Tenha em mente que dependendo do produto escolhido, não haverá uma quantidade significativa de mensagens, ou ainda poder haver muitos retweets.<br /><br />
# Configurando:

# %%
#Produto escolhido:
produto = 'macbook'

#Quantidade mínima de mensagens capturadas:
n = 500
#Quantidade mínima de mensagens para a base de treinamento:
t = 300

#Filtro de língua, escolha uma na tabela ISO 639-1.
lang = 'pt'

# %% [markdown]
# Capturando os dados do twitter:

# %%
#Cria um objeto para a captura
api = tweepy.API(auth)

#Inicia a captura, para mais detalhes: ver a documentação do tweepy
i = 1
msgs = []
for msg in tweepy.Cursor(api.search, q=produto, lang=lang).items():    
    msgs.append(msg.text.lower())
    i += 1
    if i > n:
        break

#Embaralhando as mensagens para reduzir um possível viés
shuffle(msgs)

# %% [markdown]
# Salvando os dados em uma planilha Excel:

# %%
#Verifica se o arquivo não existe para não substituir um conjunto pronto
if not os.path.isfile('./{0}.xlsx'.format(produto)):
    
    #Abre o arquivo para escrita
    writer = pd.ExcelWriter('{0}.xlsx'.format(produto))

    #divide o conjunto de mensagens em duas planilhas
    dft = pd.DataFrame({'Treinamento' : pd.Series(msgs[:t])})
    dft.to_excel(excel_writer = writer, sheet_name = 'Treinamento', index = False)

    dfc = pd.DataFrame({'Teste' : pd.Series(msgs[t:])})
    dfc.to_excel(excel_writer = writer, sheet_name = 'Teste', index = False)

    #fecha o arquivo
    writer.save()

# %% [markdown]
# ___
# ## Classificando as Mensagens
#
# Agora você deve abrir o arquivo Excel com as mensagens capturadas e classificar na Coluna B se a mensagem é relevante ou não.<br />
# Não se esqueça de colocar um nome para a coluna na célula **B1**.<br /><br />
# Fazer o mesmo na planilha de Controle.
#
# ___
# ## Montando o Classificador Naive-Bayes
#
# Com a base de treinamento montada, comece a desenvolver o classificador. Escreva o seu código abaixo:
#
# Opcionalmente:
# * Limpar as mensagens removendo os caracteres: enter, :, ", ', (, ), etc. Não remover emojis.<br />
# * Corrigir separação de espaços entre palavras e/ou emojis.
# * Propor outras limpezas/transformações que não afetem a qualidade da informação.

# %%
dados = pd.ExcelFile("macbook.xlsx",sep=",")
dados.sheet_names
Teste = dados.parse("Teste")
Treinamento = dados.parse("Treinamento")
Treinamento.Classificacao.describe()

#Renomeando classificacao para relevante e irrelevante
Treinamento.Classificacao = Treinamento.Classificacao.astype("category")
Treinamento.Classificacao.cat.categories = (["irrelevante", "relevante"])

Teste.Classificacao = Teste.Classificacao.astype("category")
Teste.Classificacao.cat.categories = (["irrelevante", "relevante"])

#Transformando em objeto para evitar erros de código
Treinamento.Classificacao = Treinamento.Classificacao.astype("object")
Teste.Classificacao = Teste.Classificacao.astype("object")

# %%
#Limpeza em Teste

Teste.Teste = Teste.Teste.replace(":","",regex=True)
Teste.Teste = Teste.Teste.replace(","," ",regex=True)
Teste.Teste = Teste.Teste.replace("()","",regex=True)
Teste.Teste = Teste.Teste.replace("-","",regex=True)
Teste.Teste = Teste.Teste.replace("@","",regex=True)
Teste.Teste = Teste.Teste.replace("ela","",regex=True)
Teste.Teste = Teste.Teste.replace("!","",regex=True)
Teste.Teste = Teste.Teste.replace("rt","",regex=True)
Teste.Teste = Teste.Teste.replace("\n","",regex=True)
Teste.Teste = Teste.Teste.replace("#","",regex=True)
Teste.Teste = Teste.Teste.replace("mas","",regex=True)
Teste.Teste = Teste.Teste.replace("-","",regex=True)

# %%
#Limpeza em Treinamento

Treinamento.Treinamento = Treinamento.Treinamento.replace(":","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace(","," ",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("()","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("-","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("@","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("ela","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("!","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("rt","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("\n","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("#","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("mas","",regex=True)
Treinamento.Treinamento = Treinamento.Treinamento.replace("-","",regex=True)



Treinamento
# Out:
#                                            Treinamento Classificacao
# 0    larissadare brunaprescovia real   vendeu um ma...   irrelevante
# 1    não ligo tanto para as paradas da apple  esse ...     relevante
# 2    gostei de um vídeo youtube https//t.co/aerirkk...   irrelevante
# 3    e fuckmylife porque comprei o macbook pro e es...     relevante
# 4    gostei de um vídeo youtube https//t.co/xswis8y...   irrelevante
# 5    bringmethegu eu achava q era caro os celulares...     relevante
# 6    que vergonha e ainda quebrei a capa do macbook...   irrelevante
# 7     tec_mundo [melhores da semana] hackers conseg...   irrelevante
# 8    o cruzeiro_news vendeu o macbook. o universo v...   irrelevante
# 9                                     quero um macbook     relevante
# 10                   ¿macbook pro de 13 o 15 pulgadas?   irrelevante
# 11    tec_mundo [melhores da semana] hackers conseg...   irrelevante
# 12                            btwgmntta  e teu macbook   irrelevante
# 13                     ilumiture preciso de um macbook     relevante
# 14   minha nova meta de vida é comprar um macbook a...     relevante
# 15             macbook resolveu dar problema de novo (     relevante
# 16           heybabss amiga q top a sra tem um macbook   irrelevante
# 17   adrenaline poderiam ter incluído um macbook pr...   irrelevante
# 18   pessoas reclamando que precisam trabalhar no i...   irrelevante
# 19   oliivgomac ihhhvanessa compra o macbook então ...   irrelevante
# 20   assim que comprar o macbook vou tar sempre foc...   irrelevante
# 21   gente se o iphone 8 realmente vier assim  vou ...   irrelevante
# 22   filipekids vai chegar pelo preço de um macbook...     relevante
# 23   gente  meu iphone 7 plus  macbook pro retina e...   irrelevante
# 24    macmagazine tópicos do mm fórum formatando ma...   irrelevante
# 25   triste ao saber que não sou hacker nem tenho u...   irrelevante
# 26    emersontsilva bom diafiz atualização do ios s...   irrelevante
# 27   gostei de um vídeo youtube https//t.co/ie8fokl...   irrelevante
# 28   amigos  bom dia. preciso trocar a fonte do meu...   irrelevante
# 29   macbook pro 2012 pifou violentamente. autoriza...   irrelevante
# ..                                                 ...           ...
# 270  comprar um macbook pro por 1€? sim  graças a f...   irrelevante
# 271  na semana de apresentação de produtos novos o ...     relevante
# 272  maldita seja a pessoa que projetou o macbook q...   irrelevante
# 273  tenho que comprar um macbook pra produzir no a...   irrelevante
# 274  galerinha que ta afim de um macbook num preço ...   irrelevante
# 275  meu white girl problem de hj é q noaii saiu e ...   irrelevante
# 276   eibode parem o que vocês estão fazendo e olhe...   irrelevante
# 277  moura_mile vou te mostrar uns lkkkkkkkkkkk eu ...     relevante
# 278  uma foto muito blogueirinha pq agora tenho um ...     relevante
# 279  poadosfundos euclarice aplicativos https//t.co...   irrelevante
# 280       comprei meu macbook pro agr eh só felicidade     relevante
# 281  esquema elétrico apple macbook pro 13 a1278  d...   irrelevante
# 282  work + café ☕️ ótima combinação 😉.job tbt macb...   irrelevante
# 283  mexi num macbook pro 15" com touch bar e amei ...     relevante
# 284  daria um bom meme "professor comunista de macb...   irrelevante
# 285  touch id do macbook deveria estar em baixo. ac...   irrelevante
# 286         eu só queria um macbook  é pedir muito????     relevante
# 287  fui lá no hotel pegar o presente que tinha che...     relevante
# 288   emersontsilva bom diafiz atualização do ios s...   irrelevante
# 289               pq macbook tem que ser tão caro mane     relevante
# 290   beatricebeamore meu macbook pro retina 13'' s...   irrelevante
# 291  gente  por um acaso eu apoiei meu ipad na t do...   irrelevante
# 292  daniliraa eu já não sou tão fã  prefiro androi...     relevante
# 293   isabafreitas mano meu vizinho bateu na poa eu...   irrelevante
# 294  timbeta tópicos do mm fórum formatando macbook...   irrelevante
# 295  aqueleditado_ o macbook vida. só tem 1 disponível   irrelevante
# 296                        eu só queria um macbook pro     relevante
# 297  senhor  deus me ajuda a comprar um imac/macboo...     relevante
# 298  epa alguem que me ofereça um macbook air 😩 o p...     relevante
# 299  15k um macbook pro aqui no br e 7k no eua. que...     relevante
#
# [300 rows x 2 columns]

# %% [markdown]
# ## Encontrando P(relevante) e P(irrelevante)

# %%
irrelevante = Treinamento.Classificacao.value_counts()[0]
relevante = Treinamento.Classificacao.value_counts()[1]

P_relevante = relevante/(relevante+irrelevante)
P_irrelevante = irrelevante/(relevante+irrelevante)

Teste.Classificacao.value_counts()
# Out:
# irrelevante    140
# relevante       60
# Name: Classificacao, dtype: int64

# %% [markdown]
# ## Encontrando a frequência das palavras

# %%
######Agrupamento de palavras sinonimas######
querer = ["queria","quer","quero","querem","queriam"]
######Relevantes######
Relevante = Treinamento[Treinamento.Classificacao == "relevante"]
R = []
dic_R = {}

for i in Relevante.Treinamento:
    R.append(i.split())
for i in R:
    for e in i:
        if e in dic_R.keys():
            dic_R[e] += 1
        else:
            dic_R[e] = 1
            

    
######Irrelevantes######        
Irrelevante = Treinamento[Treinamento.Classificacao == "irrelevante"]
I = []
dic_I = {}

for i in Irrelevante.Treinamento:
    I.append(i.split())
for i in I:
    for e in i:
        if e in dic_I.keys():
            dic_I[e] += 1
        else:
            dic_I[e] = 1
            
#####Dicionário de Probabilidades P(palavra/relevante) ou P(palavra/irrelevante)######  

#relevantes
dic_freq_R = dic_R          
for i in dic_R:
    dic_freq_R[i] = (dic_R[i]+1)/(2*len(dic_R) + len(dic_I))
    
#irrelevantes
dic_freq_I = dic_I          
for i in dic_I:
    dic_freq_I[i] = (dic_I[i]+1)/(len(dic_R) + 2*len(dic_I))

# %% [markdown]
# ## Função Classificadora

# %%
##Função que fornece uma Lista classificada
def Probabilidade(comentarios,dic_freq_R,dic_freq_I,P_relevante,P_irrelevante):
    Lista_final = []
    for i in comentarios:
        P_r = P_relevante
        P_i = P_irrelevante
        for e in i:
            #Probabilidade de ser relevante
            if e in dic_freq_R.keys():         
                P_r *= dic_freq_R[e]
            else:
                P_r *= 1/(len(dic_freq_I) + len(dic_freq_R))
            #Probabilidade de ser irrelevante
            if e in dic_freq_I.keys():     
                P_i *= dic_freq_I[e]
            else:
                P_i *= 1/(len(dic_freq_I) + len(dic_freq_R))
        if P_r >= P_i:
            Lista_final.append([i,"relevante"])
        if P_i>P_r:
            Lista_final.append([i,"irrelevante"])
    return Lista_final


##Função Classificadora
def Classificador(df,dic_freq_R,dic_freq_I,P_relevante,P_irrelevante):
    Todos = []
    for i in df.Teste:
        Todos.append(i.split())
    x = Probabilidade(Todos,dic_freq_R,dic_freq_I,P_relevante,P_irrelevante)
    #Transformando lista de palavras em uma sentença
    s = " "
    for e in x:
        e[0] = s.join(e[0])
    y=[]
    z=[]
    for i in x:
        y.append(i[0])
        z.append(i[1])

    #Criando DataFrame classificado pelo Programa
    classificado = pd.DataFrame()
    classificado["Comentário"] = pd.Series(y)
    classificado["Auto_Classificacao"] = pd.Series(z)
    return classificado

# %% [markdown]
# ___
# ## Verificando a performance
#
# Agora você deve testar o seu Classificador com a base de Testes.<br /><br />
#
# Você deve extrair as seguintes medidas:
# * Porcentagem de positivos falsos (marcados como relevante mas não são relevantes)
# * Porcentagem de positivos verdadeiros (marcado como relevante e são relevantes)
# * Porcentagem de negativos verdadeiros (marcado como não relevante e não são relevantes)
# * Porcentagem de negativos falsos (marcado como não relevante e são relevantes)
#
# Opcionalmente:
# * Criar categorias intermediárias de relevância baseado na diferença de probabilidades. Exemplo: muito relevante, relevante, neutro, irrelevante e muito irrelevante.

# %%
df = Classificador(Teste,dic_freq_R,dic_freq_I,P_relevante,P_irrelevante)

# %% [markdown]
# ## Colocando classificacoes lado a lado para avaliar performance

# %%
df["Classificacao"] = Teste.Classificacao
df
# Out:
#                                             Comentário Auto_Classificacao  \
# 0    eu tô chorando por que meu pai pegou meu macbo...        irrelevante
# 1    diogot dougdiskin grigio e esse adaptador pro ...        irrelevante
# 2    emersontsilva bom diafiz atualização do ios si...        irrelevante
# 3    a menina falando da um salve na quebrada atras...        irrelevante
# 4    larissadare brunaprescovia poanto foi falha do...        irrelevante
# 5    stephanny você quer viajar? mas ela disse q qu...        irrelevante
# 6    não uso, tenho (celinha com s5 e iphone da fil...        irrelevante
# 7    guizolio drogado de fruity loops, pra que no f...        irrelevante
# 8    depois de quase 4 anos eu descobri aonde fica ...        irrelevante
# 9    serei assim se eu ganhar um macbook dourado ht...        irrelevante
# 10   inclusive primeira vez que tenho algum colega ...        irrelevante
# 11   pm recupera macbook de músico ichuense roubado...        irrelevante
# 12   tec_mundo [melhores da semana] hackers consegu...        irrelevante
# 13   esfalcine tu tem que ser muito tapado p pagar ...        irrelevante
# 14   ultrabook &gt; macbookcomercial do ultrabookta...        irrelevante
# 15       1.000 dolares o novo iphone, preço do macbook        irrelevante
# 16   comphany_ macbook pro, tive que comprar um ada...        irrelevante
# 17   mvcmendes, tudo baum? alguém aí do loop usa um...        irrelevante
# 18   tec_mundo [melhores da semana] hackers consegu...        irrelevante
# 19   littleixneique marqueszero chediaco ah, eu não...        irrelevante
# 20     belo dia pra comprar um macbook de 12 mil reais          relevante
# 21   vi o novo macbook pro e puta que pariu, que co...        irrelevante
# 22   isabelaafreitas mano meu vizinho bateu na poa ...        irrelevante
# 23   mano eu pesquisei macbook no app do mercado li...        irrelevante
# 24   mesa de abeura do congresso dos comunistas da ...        irrelevante
# 25   rodriggodell é um macbook mid 2010. core2duo, ...        irrelevante
# 26   sério que você precisa borrar o nome macbook n...        irrelevante
# 27   followfabio sério que você precisa borrar o no...        irrelevante
# 28                  tão trist, alguém me dá um macbook          relevante
# 29   tá porra eu preciso de um macbook, meu pc não ...        irrelevante
# ..                                                 ...                ...
# 170  emersontsilva bom diafiz atualização do ios si...        irrelevante
# 171  macmagazine tópicos do mm fórum formatando mac...        irrelevante
# 172  gostei de um vídeo youtube https//t.co/nh31evj...        irrelevante
# 173  jaaaobr marqueszero chediaco mas pelo preço do...        irrelevante
# 174  meirellesbel_ _hannah_mendes_ macbook e uma me...        irrelevante
# 175  duda falando que o macbook é barato, sim, quas...        irrelevante
# 176                    quero muito um macbook como faz          relevante
# 177  keison_alh daniliraa eu já não sou tão fã, pre...          relevante
# 178  emersontsilva bom diafiz atualização do ios si...        irrelevante
# 179                   preciso comprar um apple macbook        irrelevante
# 180  bom diafiz atualização do ios sierra de 5gb p/...        irrelevante
# 181  superunkowmn e o mini macbook ao lado dele so ...        irrelevante
# 182  drogado de fruity loops, pra que no futuro eu ...        irrelevante
# 183  saga carregador continua. alguém tem carregado...        irrelevante
# 184  roubei o macbook do coroa, vou ver filme ate d...        irrelevante
# 185                         comprei um macbook pro 💻❤️        irrelevante
# 186  quero stickers pra colar no meu macbook novoooooo        irrelevante
# 187  sério, eu nunca sonhei em ter um macbook mas e...        irrelevante
# 188   sério que contrataram um programador de macbook?        irrelevante
# 189  emersontsilva bom diafiz atualização do ios si...        irrelevante
# 190  macbook do ramon (20102017) rip."não aguentou ...        irrelevante
# 191  alguém tem um carregador velho, quebrado ou nã...        irrelevante
# 192  cdnleon comprei um macbook pro top de linha em...        irrelevante
# 193  emersontsilva bom diafiz atualização do ios si...        irrelevante
# 194  e assim caminha a humanidade https//t.co/kcjxs...        irrelevante
# 195          meu macbook voltou e tá novinho de novo 😍        irrelevante
# 196  anapaulagomess tô vendendo o meu maquinhomacbo...        irrelevante
# 197  edisonlsm teclado bom só de thinkpad e macbook...        irrelevante
# 198  queria tanto um carregador novo pro meu macboo...        irrelevante
# 199  deus tira de mim essa vontade de querer compra...        irrelevante
#
#     Classificacao
# 0       relevante
# 1     irrelevante
# 2     irrelevante
# 3       relevante
# 4     irrelevante
# 5       relevante
# 6       relevante
# 7       relevante
# 8     irrelevante
# 9       relevante
# 10    irrelevante
# 11    irrelevante
# 12    irrelevante
# 13      relevante
# 14      relevante
# 15      relevante
# 16    irrelevante
# 17    irrelevante
# 18    irrelevante
# 19      relevante
# 20      relevante
# 21      relevante
# 22    irrelevante
# 23    irrelevante
# 24    irrelevante
# 25    irrelevante
# 26    irrelevante
# 27    irrelevante
# 28      relevante
# 29      relevante
# ..            ...
# 170   irrelevante
# 171   irrelevante
# 172   irrelevante
# 173     relevante
# 174     relevante
# 175     relevante
# 176     relevante
# 177   irrelevante
# 178   irrelevante
# 179     relevante
# 180   irrelevante
# 181   irrelevante
# 182     relevante
# 183   irrelevante
# 184   irrelevante
# 185     relevante
# 186   irrelevante
# 187     relevante
# 188   irrelevante
# 189   irrelevante
# 190   irrelevante
# 191   irrelevante
# 192   irrelevante
# 193   irrelevante
# 194   irrelevante
# 195     relevante
# 196   irrelevante
# 197     relevante
# 198   irrelevante
# 199     relevante
#
# [200 rows x 3 columns]

# %%
L_performance_relevante = []
L_performance_irrelevante = []


for i in range(len(df)):
    if df.Classificacao[i] == 'relevante':
        if df.Auto_Classificacao[i] == 'relevante':
            L_performance_relevante.append('positivos verdadeiros')
        elif df.Auto_Classificacao[i] == 'irrelevante':
            L_performance_relevante.append('negativos falsos')
    elif df.Classificacao[i] == 'irrelevante':
        if df.Auto_Classificacao[i] == 'irrelevante':
            L_performance_irrelevante.append('negativos verdadeiros')
        elif df.Auto_Classificacao[i] == 'relevante':
            L_performance_irrelevante.append('positivos falsos')
            
            
porcentagem_relevante = pd.Series(L_performance_relevante)
a = (porcentagem_relevante.value_counts())/60 #total de comentarios relevante

porcentagem_irrelevante = pd.Series(L_performance_irrelevante)
b = (porcentagem_irrelevante.value_counts())/140

print(a)
print("\n")
print(b)
# Out:
# negativos falsos         0.8
# positivos verdadeiros    0.2
# dtype: float64
#
#
# negativos verdadeiros    0.957143
# positivos falsos         0.042857
# dtype: float64

# %% [markdown]
# ___
# ## Concluindo
#
# Escreva aqui a sua conclusão.<br />
# Faça um comparativo qualitativo sobre as medidas obtidas.<br />
# Explique como são tratadas as mensagens com dupla negação e sarcasmo.<br />
# Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?<br />
#
# Opcionalmente:
# * Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
# * Propor diferentes cenários de uso para o classificador Naive-Bayes. Cenários sem intersecção com este projeto.
# * Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer e material de pesquisa sobre o assunto).

# %% [markdown]
# ### conclusao
#
# Partindo da performance obtida, é possível notar que o programa tende a classificar a maioria das mensagens como irrelevantes(negativos verdadeiros = 95%, enquanto positivos verdadeiros = 20%).
#
# Um dos principais motivos desse resultado se deve ao fato de que a principal palavra chave do tema analisado, "macbook", se encontra em absolutamente todos os comentários, o que acaba relevando a sua importância no momento da classificação(essa palavra deixa de ter um peso significativo). Assim, a sua precisão acaba sendo prejudicada pelo fato de que a maioria dos comentários sobre esse produto são irrelevantes(+- 70%), o que compromete o processo de machine learning.
#
# Outro Motivo para isso é que não existe um meio de tratamento de mensagens com dupla negação e sarcasmo, há apenas a filtragem de termos que não agregam na classificação(como: @, "e", "#" e etc.).
#
# Apesar disso, o programa mostra grande potencial para a classificação adequada das mensagens. Com futuras iterações serão implementadas técnicas avançadas de filtragem, que agruparão palavras sinônimas(como: "quer" e "queria") em um uníco grupo, o que significativamente aumentará  a frequencia dessas palavras, o que com certeza resultará em melhores resultados dessa análise.
#
# Por Outro lado, foi possível observar uma tendência de comentários do tipo: quero um macbook, preciso de um macbook etc. Isso significa que esse programa classificador foi capaz de encontrar pessoas que querem comprar o macbook da apple. Com essa informação, é possível expor esses usúario às propragandas do macbook, o que provavelmente aumentará as vendas do laptop.
